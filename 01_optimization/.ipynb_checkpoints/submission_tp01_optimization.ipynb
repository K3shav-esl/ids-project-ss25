# %% [markdown]
# # IDS Challenge: Sub-Projekt 01 Optimization
# ## Results
#
# ### Group: ___
# ### Tutor: ___
#
# This is your workspace - implement all submission-relevant functions and elements here and add short text-descriptions that explain your steps. (See `README_EN.ipynb`)

# %%
from main import main
main()
# Out:
# Loading machine points data...
# Loading travel-service-time matrix...
#
# Generating initial overview plots...
# Optimizing routes for existing employee rounds...
#
# --- Optimizing Gianni's Route (20 machines) ---
# Gianni's optimized tour time: 06h 21m 57.40s
# Gianni's optimized sequence: [0, 5, 7, 17, 6, 14, 19, 15, 3, 16, 11, 12, 10, 18, 13, 9, 2, 4, 1, 8, 0]
# --- Optimizing lissi's Route (24 machines) ---
# lissi's optimized tour time: 07h 44m 12.51s
# lissi's optimized sequence: [0, 25, 36, 40, 31, 27, 35, 38, 30, 20, 34, 29, 24, 23, 26, 42, 21, 32, 39, 22, 41, 37, 33, 28, 0]
# --- Optimizing ben's Route (13 machines) ---
# ben's optimized tour time: 04h 47m 47.91s
# ben's optimized sequence: [0, 43, 45, 49, 48, 44, 51, 54, 50, 52, 46, 53, 47, 0]
# Assessing robot fleet sizing...
#
# --- Robot Assessment for Gianni's Route ---
# Gianni's route fits within an 8-hour shift (08h 00m 0.00s).
#   - Robot Type 1 (10h battery) is required.
#
# Exploring advanced scenarios (e.g., K-Means clustering for 2 robots)...
#
# Optimization complete. Review plots and console output for results.
